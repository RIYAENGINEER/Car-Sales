# %% [markdown]
# <a href="https://colab.research.google.com/github/RIYAENGINEER/Car-Sales/blob/main/carsales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/Car_sales.csv")
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df["Latest_Launch"]=pd.to_datetime(df["Latest_Launch"],format="%m/%d/%Y")

# %%
df
# Out:
#      Manufacturer  Model  Sales_in_thousands  __year_resale_value  \
# 0               0     79              16.919               16.360
# 1               0    143              39.384               19.875
# 2               0     25              14.114               18.225
# 3               0    115               8.588               29.725
# 4               1      8              20.397               22.255
# ..            ...    ...                 ...                  ...
# 152            29    148               3.545                  NaN
# 153            29    125              15.245                  NaN
# 154            29    149              17.531                  NaN
# 155            29     24               3.493                  NaN
# 156            29    126              18.969                  NaN
#
#      Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0               1               21.50          1.8       140.0      101.2
# ...

# %%
print(df.isnull().sum())
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
df_clean = df.dropna(subset=['__year_resale_value'])

# %%
df
# Out:
#      Manufacturer  Model  Sales_in_thousands  __year_resale_value  \
# 0               0     79              16.919               16.360
# 1               0    143              39.384               19.875
# 2               0     25              14.114               18.225
# 3               0    115               8.588               29.725
# 4               1      8              20.397               22.255
# ..            ...    ...                 ...                  ...
# 152            29    148               3.545                  NaN
# 153            29    125              15.245                  NaN
# 154            29    149              17.531                  NaN
# 155            29     24               3.493                  NaN
# 156            29    126              18.969                  NaN
#
#      Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0               1               21.50          1.8       140.0      101.2
# ...

# %%
print(df.isnull().sum())
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
df['__year_resale_value'] = df['__year_resale_value'].fillna(0)  # or 'unknown', 999, etc.

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                0.000
# 153        Volvo      S70              15.245                0.000
# 154        Volvo      V70              17.531                0.000
# 155        Volvo      C70               3.493                0.000
# 156        Volvo      S80              18.969                0.000
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df = df.dropna(subset=['Price_in_thousands'])

# %%
print(df.isnull().sum())
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      0
# Engine_size             0
# Horsepower              0
# Wheelbase               0
# Width                   0
# Length                  0
# Curb_weight             1
# Fuel_capacity           0
# Fuel_efficiency         2
# Latest_Launch           0
# Power_perf_factor       0
# dtype: int64

# %%
df = df.dropna(subset=['Price_in_thousands','Fuel_efficiency','Curb_weight'])

# %%
print(df.isnull().sum())
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    35
# Vehicle_type            0
# Price_in_thousands      0
# Engine_size             0
# Horsepower              0
# Wheelbase               0
# Width                   0
# Length                  0
# Curb_weight             0
# Fuel_capacity           0
# Fuel_efficiency         0
# Latest_Launch           0
# Power_perf_factor       0
# dtype: int64

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
for j in df.select_dtypes(include="object").columns:
  print(j,df[j].unique())
# Out:
# Manufacturer ['Acura' 'Audi' 'BMW' 'Buick' 'Cadillac' 'Chevrolet' 'Chrysler' 'Dodge'
#  'Ford' 'Honda' 'Hyundai' 'Infiniti' 'Jaguar' 'Jeep' 'Lexus' 'Lincoln'
#  'Mitsubishi' 'Mercury' 'Mercedes-B' 'Nissan' 'Oldsmobile' 'Plymouth'
#  'Pontiac' 'Porsche' 'Saab' 'Saturn' 'Subaru' 'Toyota' 'Volkswagen'
#  'Volvo']
# Model ['Integra' 'TL' 'RL' 'A4' 'A6' 'A8' '323i' '328i' '528i' 'Century' 'Regal'
#  'Park Avenue' 'LeSabre' 'DeVille' 'Eldorado' 'Catera' 'Escalade'
#  'Cavalier' 'Malibu' 'Lumina' 'Monte Carlo' 'Camaro' 'Corvette' 'Prizm'
#  'Metro' 'Impala' 'Sebring Coupe' 'Sebring Conv.' 'Concorde' 'Cirrus'
#  'LHS' '300M' 'Neon' 'Avenger' 'Stratus' 'Viper' 'Ram Pickup' 'Ram Wagon'
#  'Ram Van' 'Dakota' 'Durango' 'Caravan' 'Escort' 'Mustang' 'Contour'
#  'Taurus' 'Focus' 'Crown Victoria' 'Explorer' 'Windstar' 'Expedition'
#  'Ranger' 'F-Series' 'Civic' 'Accord' 'CR-V' 'Passport' 'Odyssey' 'Accent'
#  'Elantra' 'Sonata' 'I30' 'S-Type' 'Wrangler' 'Cherokee' 'Grand Cherokee'
# ...

# %%
from sklearn.preprocessing import LabelEncoder #scikit learn
df_LableEncoder=LabelEncoder()

# %%
for j in df.select_dtypes(include="object").columns:
  df[j]=df_LableEncoder.fit_transform(df[j])

# %%
df
# Out:
#      Manufacturer  Model  Sales_in_thousands  __year_resale_value  \
# 0               0     78              16.919               16.360
# 1               0    139              39.384               19.875
# 3               0    112               8.588               29.725
# 4               1      8              20.397               22.255
# 5               1      9              18.780               23.555
# ..            ...    ...                 ...                  ...
# 152            29    143               3.545                  NaN
# 153            29    122              15.245                  NaN
# 154            29    144              17.531                  NaN
# 155            29     24               3.493                  NaN
# 156            29    123              18.969                  NaN
#
#      Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0               1               21.50          1.8       140.0      101.2
# ...

# %%
df.corr()
# Out:
#                      Manufacturer     Model  Sales_in_thousands  \
# Manufacturer             1.000000  0.089773           -0.166702
# Model                    0.089773  1.000000           -0.014742
# Sales_in_thousands      -0.166702 -0.014742            1.000000
# __year_resale_value      0.006618 -0.132309           -0.275426
# Vehicle_type            -0.019287 -0.226068           -0.243023
# Price_in_thousands      -0.045367 -0.068969           -0.301850
# Engine_size             -0.270818  0.054455            0.027716
# Horsepower              -0.200931 -0.041360           -0.192519
# Wheelbase               -0.287816  0.085473            0.360186
# Width                   -0.299179  0.099746            0.143664
# Length                  -0.306711  0.021307            0.260162
# Curb_weight             -0.179964  0.082624            0.008784
# Fuel_capacity           -0.161189  0.089842            0.087437
# Fuel_efficiency          0.108868 -0.081147           -0.016474
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         152 non-null    int64
#  1   Model                152 non-null    int64
#  2   Sales_in_thousands   152 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         152 non-null    int64
#  5   Price_in_thousands   152 non-null    float64
#  6   Engine_size          152 non-null    float64
#  7   Horsepower           152 non-null    float64
#  8   Wheelbase            152 non-null    float64
#  9   Width                152 non-null    float64
#  10  Length               152 non-null    float64
#  11  Curb_weight          152 non-null    float64
#  12  Fuel_capacity        152 non-null    float64
#  13  Fuel_efficiency      152 non-null    float64
#  14  Latest_Launch        152 non-null    datetime64[ns]
# ...
